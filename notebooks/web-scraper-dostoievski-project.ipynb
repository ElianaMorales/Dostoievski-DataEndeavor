# %% [markdown]
# # Web Scraping with BeautifulSoup
#
# **Description:**
# This web scraper is designed to collect data on Fyodor Dostoevsky's literary works, including the titles, publication years, and additional information. The scraper targets a specific website that contains a curated list of Dostoevsky's works along with publication details. Using Python and popular libraries such as BeautifulSoup and pandas, the script navigates through the HTML structure of the webpage, extracts relevant information, and organizes it into a structured DataFrame. The resulting dataset provides a comprehensive overview of Dostoevsky's works, facilitating further analysis and exploration within a Jupyter notebook environment.
#
# The obtained dataset is not only organized within a Jupyter notebook but also seamlessly exported to a Google Sheet through the Google Sheets API. This integration enables real-time collaboration, storage, and further analysis of the collected data on the cloud.
#
# **Dependencies:**
#
# * beautifulsoup4: For parsing HTML content.
# * pandas: For data manipulation and storage.
# * requests: For fetching HTML content from the website.

# %% [markdown]
# **1. Web Scraping Script**

# %%
# Import libraries

from bs4 import BeautifulSoup
import requests

# %%
# Obtains the raw data from the url

url = 'https://www.addall.com/books-in-order/fyodor-dostoevsky/'

page = requests.get(url)

soup = BeautifulSoup(page.text, 'html.parser')

# %%
# Selecting the main divs that contain the categories, descriptions, images, and titles

category_of_books = soup.find('div', class_='entry-content')

images_of_books = soup.find('div', class_='img-card')

titles_images_of_books = soup.find_all('div', class_="img-a")

description_of_books = soup.find_all('div', class_="over-card")

# %%
books = {}
book_categories = []
book_titles = []
book_images=[]
book_images_titles=[]
book_descriptions_titles = []
book_details_descr={}
book_details_img={}

categories = category_of_books.find_all('h2')
titles = category_of_books.find_all('div', class_='list-card')

# Adding the categories of the categories div to a list. 
# This list will become the keys of the dictionary that will store the titles as its values

for category in categories:
    book_categories.append(category.text)
    
for title in titles:
    book_titles.append(title.text)
    
for i in range (len(book_titles)):
    books[book_categories[i]] = book_titles[i]
    
# Adding the titles in the descriptions div to a list.
# This list will become the keys of the dictionary that will store the descriptions as its values

for title in description_of_books:
    # Find the 'a' tag within each div
    title_of_desc = title.find('a')
    book_descriptions_titles.append(title_of_desc.text)
    
for description in description_of_books:
    # Find the 'p' tag within each div
    description = description.find('p')
    book_descriptions.append(description.text)

for i in range(len(book_descriptions_titles)):
    book_details_descr[book_descriptions_titles[i]] = book_descriptions[i]

# %% [markdown]
# **2. DataFrame creation**

# %%
import pandas as pd

# %%
# We have two dictionaries, so two datasets were created

df = pd.DataFrame.from_dict(books, orient='index')
df2 = pd.DataFrame.from_dict(book_details, orient = 'index')

# Because the dfs were created from dicts, the key will be used as index. We are avoiding that by reseting the index.
# This adds a numerated index columns
# After that, we proceed to add the headers for the new columns

df.reset_index(inplace=True)
df.columns = ['Category', 'Title']

df2.reset_index(inplace=True)
df2.columns=['Title', 'Description']

df
# Out:
#                                        Category  \
# 0        Standalone Novels In Publication Order
# 1  Short Story Collections In Publication Order
# 2     Writer’s Diary Books In Publication Order
# 3        Non-Fiction Books In Publication Order
#
#                                                Title
# 0  \n\nThe Double (1846)\nPoor Folk / Poor People...
# 1  \n\nPoor Folk and Other Stories (1845)\nAn Hon...
# 2  \n\nA Writer’s Diary, Volume One, 1873-1876 (1...
# 3  \n\nWinter Notes on Summer Impressions (1863)\...

# %% [markdown]
# **3. Data Cleansing**

# %%
# At the beginning of the Title rows there were escape character. This removes them
df['Title'] = df['Title'].str.split('\n\n').str[1].str.strip()
df
# Out:
#                                        Category  \
# 0        Standalone Novels In Publication Order
# 1  Short Story Collections In Publication Order
# 2     Writer’s Diary Books In Publication Order
# 3        Non-Fiction Books In Publication Order
#
#                                                Title
# 0  The Double (1846)\nPoor Folk / Poor People (18...
# 1  Poor Folk and Other Stories (1845)\nAn Honest ...
# 2  A Writer’s Diary, Volume One, 1873-1876 (1886)...
# 3  Winter Notes on Summer Impressions (1863)\nDos...

# %%
#All the titles of a particular category were in a single row.
#This puts each title in a separate row

df['Title'] = df['Title'].str.split('\n')
df = df.explode('Title')
df
# Out:
#                                        Category  \
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 0        Standalone Novels In Publication Order
# 1  Short Story Collections In Publication Order
# 1  Short Story Collections In Publication Order
# 1  Short Story Collections In Publication Order
# 1  Short Story Collections In Publication Order
# 1  Short Story Collections In Publication Order
# 1  Short Story Collections In Publication Order
# 1  Short Story Collections In Publication Order
# 1  Short Story Collections In Publication Order
# 1  Short Story Collections In Publication Order
# 1  Short Story Collections In Publication Order
# 2     Writer’s Diary Books In Publication Order
# 2     Writer’s Diary Books In Publication Order
# 3        Non-Fiction Books In Publication Order
# 3        Non-Fiction Books In Publication Order
# 3        Non-Fiction Books In Publication Order
# 3        Non-Fiction Books In Publication Order
# 3        Non-Fiction Books In Publication Order
#
#                                                Title
# 0                                  The Double (1846)
# 0                     Poor Folk / Poor People (1846)
# 0                                The Landlady (1847)
# 0                                White Nights (1848)
# 0                               Uncle’s Dream (1859)
# 0  The Insulted and Injured / Humiliated and Insu...
# 0  The House of the Dead / Notes from a Dead Hous...
# 0                  Notes from the Underground (1864)
# 0                        Crime and Punishment (1866)
# 0                                 The Gambler (1866)
# 0                                   The Idiot (1869)
# 0                         The Eternal Husband (1870)
# 0         Demons / The Devils / The Possessed (1872)
# 0                              The Adolescent (1875)
# 0               The Dream of a Ridiculous Man (1877)
# 0                      The Brothers Karamazov (1879)
# 1                 Poor Folk and Other Stories (1845)
# 1           An Honest Thief and Other Stories (1848)
# 1         A Gentle Creature and Other Stories (1876)
# 1                        The Grand Inquisitor (1879)
# 1       The Eternal Husband and Other Stories (1890)
# 1               The Gambler and Other Stories (1914)
# 1      Great Short Works of Fyodor Dostoevsky (1968)
# 1               The Crocodile and Other Tales (1973)
# 1             Uncle’s Dream and Other Stories (1989)
# 1  The Best Short Stories of Fyodor Dostoevsky (2...
# 2     A Writer’s Diary, Volume One, 1873-1876 (1886)
# 2     A Writer’s Diary, Volume Two, 1877-1881 (1886)
# 3          Winter Notes on Summer Impressions (1863)
# 3       Dostoevsky: Letters and Reminiscences (1923)
# 3      Selected Letters of Fyodor Dostoyevsky (1987)
# 3                 Complete Letters, 1860-1867 (1989)
# 3            Dostoevsky’s Occasional Writings (1997)

# %%
# In the titles, the YoP were included. This creates a separate column for it.

df['YoP'] = df['Title'].str.extract(r'(\d{4})')

#Removes the extra parnthesis that remain from the previous transformation

df['Title'] = df['Title'].str.split('(').str[0].str.strip()

#Removes the alternative titles

df['Title'] = df['Title'].str.split(' /').str[0].str.strip()
df['Title'] = df['Title'].str.split(', 1').str[0].str.strip()

#Removes the alternative titles
df2['Title'] = df2['Title'].str.split(' /').str[0].str.strip()

# Merges the two dfs using the titles as common column

df = pd.merge(df, df2, how='left', on='Title')
df.reset_index(inplace=True)
df = df.drop('index', axis=1)
df
# Out:
#                                         Category  \
# 0         Standalone Novels In Publication Order
# 1         Standalone Novels In Publication Order
# 2         Standalone Novels In Publication Order
# 3         Standalone Novels In Publication Order
# 4         Standalone Novels In Publication Order
# 5         Standalone Novels In Publication Order
# 6         Standalone Novels In Publication Order
# 7         Standalone Novels In Publication Order
# 8         Standalone Novels In Publication Order
# 9         Standalone Novels In Publication Order
# 10        Standalone Novels In Publication Order
# 11        Standalone Novels In Publication Order
# 12        Standalone Novels In Publication Order
# 13        Standalone Novels In Publication Order
# 14        Standalone Novels In Publication Order
# 15        Standalone Novels In Publication Order
# 16  Short Story Collections In Publication Order
# 17  Short Story Collections In Publication Order
# 18  Short Story Collections In Publication Order
# 19  Short Story Collections In Publication Order
# 20  Short Story Collections In Publication Order
# 21  Short Story Collections In Publication Order
# 22  Short Story Collections In Publication Order
# 23  Short Story Collections In Publication Order
# 24  Short Story Collections In Publication Order
# 25  Short Story Collections In Publication Order
# 26     Writer’s Diary Books In Publication Order
# 27     Writer’s Diary Books In Publication Order
# 28        Non-Fiction Books In Publication Order
# 29        Non-Fiction Books In Publication Order
# 30        Non-Fiction Books In Publication Order
# 31        Non-Fiction Books In Publication Order
# 32        Non-Fiction Books In Publication Order
#
#                                           Title   YoP  \
# 0                                    The Double  1846
# 1                                     Poor Folk  1846
# 2                                  The Landlady  1847
# 3                                  White Nights  1848
# 4                                 Uncle’s Dream  1859
# 5                      The Insulted and Injured  1861
# 6                         The House of the Dead  1862
# 7                    Notes from the Underground  1864
# 8                          Crime and Punishment  1866
# 9                                   The Gambler  1866
# 10                                    The Idiot  1869
# 11                          The Eternal Husband  1870
# 12                                       Demons  1872
# 13                               The Adolescent  1875
# 14                The Dream of a Ridiculous Man  1877
# 15                       The Brothers Karamazov  1879
# 16                  Poor Folk and Other Stories  1845
# 17            An Honest Thief and Other Stories  1848
# 18          A Gentle Creature and Other Stories  1876
# 19                         The Grand Inquisitor  1879
# 20        The Eternal Husband and Other Stories  1890
# 21                The Gambler and Other Stories  1914
# 22       Great Short Works of Fyodor Dostoevsky  1968
# 23                The Crocodile and Other Tales  1973
# 24              Uncle’s Dream and Other Stories  1989
# 25  The Best Short Stories of Fyodor Dostoevsky  2007
# 26                 A Writer’s Diary, Volume One  1873
# 27                 A Writer’s Diary, Volume Two  1877
# 28           Winter Notes on Summer Impressions  1863
# 29        Dostoevsky: Letters and Reminiscences  1923
# 30       Selected Letters of Fyodor Dostoyevsky  1987
# 31                             Complete Letters  1860
# 32             Dostoevsky’s Occasional Writings  1997
#
#                                           Description
# 0   At once a comic masterpiece and a penetrating ...
# 1   This novel brought its 24 year old author crit...
# 2                                                 NaN
# 3                                                 NaN
# 4                                                 NaN
# 5   1915. Dostoevsky, Russian novelist, is conside...
# 6   Accused of political subversion as a young man...
# 7   ‘Notes from Underground translated in English ...
# 8   Crime and Punishment, by Fyodor Dostoevsky, is...
# 9                                                 NaN
# 10  The Idiot, by Fyodor Dostoevsky, is part of th...
# 11  The most monstrous monster is the monster with...
# 12  In 1869 a young Russian was strangled, shot th...
# 13  Book Jacket Status: JacketedThis superb new tr...
# 14                                                NaN
# 15  The Brothers Karamazov, by Fyodor Dostoevsky, ...
# 16  With their penetrating psychological insight a...
# 17  CONTENTS An Honest Thief Uncle’s Dream A Novel...
# 18  In these stories, Dostoevsky explores both the...
# 19  This new edition presents ‘The Grand Inquisito...
# 20  The Eternal Husband and Other Stories brings t...
# 21  A new selection of seven of Dostoyevsky’s best...
# 22  The shorter works of one of the world’s greate...
# 23  ‘The Crocodile’ is a wickedly ironic ‘true sto...
# 24                                                NaN
# 25  This collection, unique to the Modern Library,...
# 26                                                NaN
# 27                                                NaN
# 28  In June 1862, Dostoevsky left Petersburg on hi...
# 29                                                NaN
# 30                                                NaN
# 31                                                NaN
# 32  This classic collection of articles, sketches,...

# %%
# Removing the 'In Publication Order' substring from the categories

df['Category'] = df['Category'].str.replace('In Publication Order', '').str.strip()
df
# Out:
#                    Category                                        Title  \
# 0         Standalone Novels                                   The Double
# 1         Standalone Novels                                    Poor Folk
# 2         Standalone Novels                                 The Landlady
# 3         Standalone Novels                                 White Nights
# 4         Standalone Novels                                Uncle’s Dream
# 5         Standalone Novels                     The Insulted and Injured
# 6         Standalone Novels                        The House of the Dead
# 7         Standalone Novels                   Notes from the Underground
# 8         Standalone Novels                         Crime and Punishment
# 9         Standalone Novels                                  The Gambler
# 10        Standalone Novels                                    The Idiot
# 11        Standalone Novels                          The Eternal Husband
# 12        Standalone Novels                                       Demons
# 13        Standalone Novels                               The Adolescent
# 14        Standalone Novels                The Dream of a Ridiculous Man
# 15        Standalone Novels                       The Brothers Karamazov
# 16  Short Story Collections                  Poor Folk and Other Stories
# 17  Short Story Collections            An Honest Thief and Other Stories
# 18  Short Story Collections          A Gentle Creature and Other Stories
# 19  Short Story Collections                         The Grand Inquisitor
# 20  Short Story Collections        The Eternal Husband and Other Stories
# 21  Short Story Collections                The Gambler and Other Stories
# 22  Short Story Collections       Great Short Works of Fyodor Dostoevsky
# 23  Short Story Collections                The Crocodile and Other Tales
# 24  Short Story Collections              Uncle’s Dream and Other Stories
# 25  Short Story Collections  The Best Short Stories of Fyodor Dostoevsky
# 26     Writer’s Diary Books                 A Writer’s Diary, Volume One
# 27     Writer’s Diary Books                 A Writer’s Diary, Volume Two
# 28        Non-Fiction Books           Winter Notes on Summer Impressions
# 29        Non-Fiction Books        Dostoevsky: Letters and Reminiscences
# 30        Non-Fiction Books       Selected Letters of Fyodor Dostoyevsky
# 31        Non-Fiction Books                             Complete Letters
# 32        Non-Fiction Books             Dostoevsky’s Occasional Writings
#
#      YoP                                        Description
# 0   1846  At once a comic masterpiece and a penetrating ...
# 1   1846  This novel brought its 24 year old author crit...
# 2   1847                                                NaN
# 3   1848                                                NaN
# 4   1859                                                NaN
# 5   1861  1915. Dostoevsky, Russian novelist, is conside...
# 6   1862  Accused of political subversion as a young man...
# 7   1864  ‘Notes from Underground translated in English ...
# 8   1866  Crime and Punishment, by Fyodor Dostoevsky, is...
# 9   1866                                                NaN
# 10  1869  The Idiot, by Fyodor Dostoevsky, is part of th...
# 11  1870  The most monstrous monster is the monster with...
# 12  1872  In 1869 a young Russian was strangled, shot th...
# 13  1875  Book Jacket Status: JacketedThis superb new tr...
# 14  1877                                                NaN
# 15  1879  The Brothers Karamazov, by Fyodor Dostoevsky, ...
# 16  1845  With their penetrating psychological insight a...
# 17  1848  CONTENTS An Honest Thief Uncle’s Dream A Novel...
# 18  1876  In these stories, Dostoevsky explores both the...
# 19  1879  This new edition presents ‘The Grand Inquisito...
# 20  1890  The Eternal Husband and Other Stories brings t...
# 21  1914  A new selection of seven of Dostoyevsky’s best...
# 22  1968  The shorter works of one of the world’s greate...
# 23  1973  ‘The Crocodile’ is a wickedly ironic ‘true sto...
# 24  1989                                                NaN
# 25  2007  This collection, unique to the Modern Library,...
# 26  1873                                                NaN
# 27  1877                                                NaN
# 28  1863  In June 1862, Dostoevsky left Petersburg on hi...
# 29  1923                                                NaN
# 30  1987                                                NaN
# 31  1860                                                NaN
# 32  1997  This classic collection of articles, sketches,...

# %%
# Cleaning NaN values since the json encoder in python does not allow NaN values for parsing

df = df.fillna('No Description')
df
# Out:
#                    Category                                        Title  \
# 0         Standalone Novels                                   The Double
# 1         Standalone Novels                                    Poor Folk
# 2         Standalone Novels                                 The Landlady
# 3         Standalone Novels                                 White Nights
# 4         Standalone Novels                                Uncle’s Dream
# 5         Standalone Novels                     The Insulted and Injured
# 6         Standalone Novels                        The House of the Dead
# 7         Standalone Novels                   Notes from the Underground
# 8         Standalone Novels                         Crime and Punishment
# 9         Standalone Novels                                  The Gambler
# 10        Standalone Novels                                    The Idiot
# 11        Standalone Novels                          The Eternal Husband
# 12        Standalone Novels                                       Demons
# 13        Standalone Novels                               The Adolescent
# 14        Standalone Novels                The Dream of a Ridiculous Man
# 15        Standalone Novels                       The Brothers Karamazov
# 16  Short Story Collections                  Poor Folk and Other Stories
# 17  Short Story Collections            An Honest Thief and Other Stories
# 18  Short Story Collections          A Gentle Creature and Other Stories
# 19  Short Story Collections                         The Grand Inquisitor
# 20  Short Story Collections        The Eternal Husband and Other Stories
# 21  Short Story Collections                The Gambler and Other Stories
# 22  Short Story Collections       Great Short Works of Fyodor Dostoevsky
# 23  Short Story Collections                The Crocodile and Other Tales
# 24  Short Story Collections              Uncle’s Dream and Other Stories
# 25  Short Story Collections  The Best Short Stories of Fyodor Dostoevsky
# 26     Writer’s Diary Books                 A Writer’s Diary, Volume One
# 27     Writer’s Diary Books                 A Writer’s Diary, Volume Two
# 28        Non-Fiction Books           Winter Notes on Summer Impressions
# 29        Non-Fiction Books        Dostoevsky: Letters and Reminiscences
# 30        Non-Fiction Books       Selected Letters of Fyodor Dostoyevsky
# 31        Non-Fiction Books                             Complete Letters
# 32        Non-Fiction Books             Dostoevsky’s Occasional Writings
#
#      YoP                                        Description
# 0   1846  At once a comic masterpiece and a penetrating ...
# 1   1846  This novel brought its 24 year old author crit...
# 2   1847                                     No Description
# 3   1848                                     No Description
# 4   1859                                     No Description
# 5   1861  1915. Dostoevsky, Russian novelist, is conside...
# 6   1862  Accused of political subversion as a young man...
# 7   1864  ‘Notes from Underground translated in English ...
# 8   1866  Crime and Punishment, by Fyodor Dostoevsky, is...
# 9   1866                                     No Description
# 10  1869  The Idiot, by Fyodor Dostoevsky, is part of th...
# 11  1870  The most monstrous monster is the monster with...
# 12  1872  In 1869 a young Russian was strangled, shot th...
# 13  1875  Book Jacket Status: JacketedThis superb new tr...
# 14  1877                                     No Description
# 15  1879  The Brothers Karamazov, by Fyodor Dostoevsky, ...
# 16  1845  With their penetrating psychological insight a...
# 17  1848  CONTENTS An Honest Thief Uncle’s Dream A Novel...
# 18  1876  In these stories, Dostoevsky explores both the...
# 19  1879  This new edition presents ‘The Grand Inquisito...
# 20  1890  The Eternal Husband and Other Stories brings t...
# 21  1914  A new selection of seven of Dostoyevsky’s best...
# 22  1968  The shorter works of one of the world’s greate...
# 23  1973  ‘The Crocodile’ is a wickedly ironic ‘true sto...
# 24  1989                                     No Description
# 25  2007  This collection, unique to the Modern Library,...
# 26  1873                                     No Description
# 27  1877                                     No Description
# 28  1863  In June 1862, Dostoevsky left Petersburg on hi...
# 29  1923                                     No Description
# 30  1987                                     No Description
# 31  1860                                     No Description
# 32  1997  This classic collection of articles, sketches,...

# %% [markdown]
# **4. Data Export**

# %%
# Importing libraries for Google Sheets API connection

import gspread
from oauth2client.service_account import ServiceAccountCredentials
import json

# %%
# Set up credentials
scope =['https://spreadsheets.google.com/feeds',
         'https://www.googleapis.com/auth/drive']

# For Google Sheets
credentials = ServiceAccountCredentials.from_json_keyfile_name(
    r'insert credential here', scope)
gc = gspread.authorize(credentials)

# For Google Drive
credentials_drive = ServiceAccountCredentials.from_json_keyfile_name(
    r'insert credential here', scope)
gc_drive = gspread.authorize(credentials_drive)

# %%
# Open the previouly created Google Spreadsheet

spreadsheet = gc.open('dostoievski_data')

# %%
# Getting the default sheet

sheet = spreadsheet.sheet1

# Updates the sheet with the dataframe data

sheet.update([df.columns.values.tolist()] + df.values.tolist())
# Out:
# C:\Users\Eliana\AppData\Local\Temp\ipykernel_2372\3928591322.py:6: DeprecationWarning: [Deprecated][in version 6.0.0]: Method signature's arguments 'range_name' and 'values' will change their order. We recommend using named arguments for minimal impact. In addition, the argument 'values' will be mandatory of type: 'List[List]'. (ex) Worksheet.update(values = [[]], range_name=)
#   sheet.update([df.columns.values.tolist()] + df.values.tolist())
# {'spreadsheetId': '10ej6aJMZKJOQJWmN_u7ulj0X2M7wI4QuXHVQtTU88zs',
#  'updatedRange': "'Hoja 1'!A1:D34",
#  'updatedRows': 34,
#  'updatedColumns': 4,
#  'updatedCells': 136}

# %%
# Open the spreadsheet by title
spreadsheet_title = "dostoievski_data"
spreadsheet = gc.open(spreadsheet_title)

# Print the URL of the spreadsheet
print(f"Spreadsheet URL: {spreadsheet.url}")
# Out:
# Spreadsheet URL: https://docs.google.com/spreadsheets/d/10ej6aJMZKJOQJWmN_u7ulj0X2M7wI4QuXHVQtTU88zs

# %% [markdown]
# ### Next Steps
#
# Data is ready to use in Google Sheets. The next step is to load this data in our Extraction Tool (Fivetran in this case)
